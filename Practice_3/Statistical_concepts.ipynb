# %%
import pandas as pd
import numpy as np # creating random number/distributions/linear algebra
import matplotlib.pyplot as plt
import seaborn as sns

# %%
np.random.rand()
# Out:
# 0.3387806865661238

# %%
for i in range(10):
    print(np.random.rand())
# Out:
# 0.3321214875263776
# 0.4336912556405573
# 0.9284878790924025
# 0.3312833763175759
# 0.4587172834873523
# 0.04497227231517931
# 0.5319323421818015
# 0.13172059333815633
# 0.9347148644484349
# 0.805824810073459

# %%
np.random.random(size=10)
# Out:
# array([0.70566548, 0.62638664, 0.02435014, 0.37980577, 0.68883212,
#        0.48263813, 0.09979996, 0.7343714 , 0.16019048, 0.19219227])

# %%
np.random.random(size=100)
# Out:
# array([0.43218447, 0.57163057, 0.19487433, 0.1135354 , 0.83522937,
#        0.0044948 , 0.05179333, 0.35920608, 0.50241199, 0.95101713,
#        0.28761694, 0.92778402, 0.66628213, 0.44858158, 0.25962929,
#        0.05459172, 0.17344596, 0.73582098, 0.34501112, 0.89027935,
#        0.0657201 , 0.39295856, 0.31494763, 0.4808741 , 0.97556003,
#        0.8173385 , 0.29886512, 0.41847707, 0.30813455, 0.11312893,
#        0.67331347, 0.32767296, 0.86739464, 0.08537867, 0.42895344,
#        0.54199487, 0.61955683, 0.3889772 , 0.03972469, 0.61476503,
#        0.7723314 , 0.83931917, 0.60130118, 0.39059993, 0.89618339,
#        0.27127886, 0.12228208, 0.51127808, 0.35111574, 0.13017038,
#        0.93052069, 0.85097731, 0.22128793, 0.86267295, 0.61987194,
#        0.87935257, 0.59365368, 0.97933837, 0.3921277 , 0.36405551,
#        0.16484466, 0.30111273, 0.42733214, 0.67447508, 0.01091844,
#        0.52800896, 0.58441576, 0.6628193 , 0.46311834, 0.12740235,
#        0.46324026, 0.21756094, 0.46726941, 0.82713281, 0.15064865,
#        0.10356134, 0.28818397, 0.12640498, 0.57271796, 0.58663444,
#        0.49370637, 0.01770849, 0.25666181, 0.86209649, 0.58233869,
#        0.55258425, 0.8839301 , 0.08040019, 0.5042345 , 0.10313231,
#        0.79771186, 0.10156959, 0.91067705, 0.78550227, 0.54682994,
#        0.66879329, 0.41062226, 0.9690323 , 0.76073702, 0.89450597])

# %%
np.random.uniform(size=100)
# Out:
# array([0.30761473, 0.54142157, 0.57253665, 0.10427239, 0.95417546,
#        0.06533516, 0.22879156, 0.97596396, 0.80990894, 0.84720888,
#        0.94976943, 0.58876438, 0.98762205, 0.21205142, 0.85599821,
#        0.94378009, 0.18677941, 0.54312281, 0.19009733, 0.98936044,
#        0.75688075, 0.94253429, 0.7724237 , 0.40907923, 0.49018143,
#        0.73762771, 0.73290884, 0.39316969, 0.72007904, 0.77321221,
#        0.19165552, 0.59780059, 0.14378374, 0.75358746, 0.00563574,
#        0.66003435, 0.92877138, 0.06576527, 0.11080755, 0.25696341,
#        0.95822378, 0.83789349, 0.04418307, 0.02093665, 0.35880528,
#        0.76833092, 0.61345101, 0.65936372, 0.89837427, 0.93944662,
#        0.20589661, 0.21977936, 0.26419806, 0.68689184, 0.34107384,
#        0.25050199, 0.34182204, 0.97724122, 0.30081613, 0.97202324,
#        0.94949047, 0.7335571 , 0.08304721, 0.50559438, 0.16789396,
#        0.74583638, 0.52258012, 0.16532926, 0.70750855, 0.5388446 ,
#        0.92779871, 0.74511068, 0.61261975, 0.13768102, 0.09571081,
#        0.04815087, 0.2704531 , 0.74905257, 0.7808408 , 0.48008752,
#        0.26337448, 0.81225701, 0.55762802, 0.46330716, 0.94722303,
#        0.86427155, 0.77773263, 0.05431984, 0.34900271, 0.29930528,
#        0.54726443, 0.04904207, 0.33351971, 0.10433261, 0.63387199,
#        0.17975896, 0.99090763, 0.40246512, 0.80645019, 0.37772589])

# %% [markdown]
# # 1. Plotting distributions

# %% [markdown]
# ## 1.0 Uniform distribution

# %%
sns.histplot(np.random.uniform(size=100))
plt.title('Uniform distribution')
plt.grid(alpha=.4)
plt.show()

# %%
sns.histplot(np.random.uniform(size=1000))
plt.title('Uniform distribution')
plt.grid(alpha=.4)
plt.show()

# %%
sns.histplot(np.random.uniform(size=100_000))
plt.title('Uniform distribution')
plt.grid(alpha=.4)
plt.show()

# %%
fig, (ax1, ax2, ax3) = plt.subplots(ncols=3, sharey=True, figsize=(12, 4), dpi=150)
sns.histplot(np.random.uniform(size=100), ax=ax1)
sns.histplot(np.random.uniform(size=1000), ax=ax2)
sns.histplot(np.random.uniform(size=10000), ax=ax3)
plt.show()

# %%
fig, (ax1, ax2, ax3) = plt.subplots(nrows=3, figsize=(4, 12), dpi=150)
sns.histplot(np.random.uniform(size=100), ax=ax1)
sns.histplot(np.random.uniform(size=1000), ax=ax2)
sns.histplot(np.random.uniform(size=10000), ax=ax3)
plt.show()

# %% [markdown]
# ## 1.1 Normal distribution / Bell curve / Gauss distribution

# %%
np.random.normal(size=100)
# Out:
# array([ 0.17896945, -0.09960016, -0.09315606,  0.27565661,  0.95167723,
#        -1.25916867, -2.28198329,  0.81582762, -1.28336369,  1.59896223,
#         0.09527767, -0.50880262,  0.04103939, -1.65857192,  1.54998985,
#        -1.11221166, -1.07672512, -1.31829859,  0.48551177,  0.72738649,
#         1.95680687,  0.19159729,  0.13023563, -1.03519525, -1.18680444,
#        -0.82185207, -0.8905505 , -0.76218946,  1.86326539,  0.30461316,
#         0.42495807,  0.83639569,  1.07318214,  1.0236869 , -0.95485955,
#        -0.30482447, -0.2715022 ,  1.05404819,  0.42881777,  1.10122466,
#        -0.28600628,  0.50974414,  1.56331965, -1.36910327,  0.4897777 ,
#         0.68443911,  1.55832656,  0.31997893, -0.87613838,  0.46334331,
#        -0.22543104,  0.85302843,  0.907978  , -0.18637244,  2.5379203 ,
#        -1.13156254, -0.87388776, -1.19337776,  0.27024141,  1.99114341,
#         0.87806079, -1.23627691,  0.23497789,  0.14234593, -0.09854647,
#         0.98157494, -0.81392124,  0.70321231, -0.86056308,  0.29878566,
#         0.04037053,  1.12301055,  1.20550398, -1.44570354,  0.73356396,
#        -1.06602458,  0.13127098,  0.97187299,  0.72147663,  0.16845544,
#         1.14873791, -0.65418655, -1.1893581 ,  0.92778978, -0.02493345,
#        -0.07861149,  0.18648839, -0.45587839,  0.79393148,  0.73307672,
#        -0.24926615,  0.67797665, -0.58308451, -0.73284517, -1.04193356,
#        -0.1953713 , -0.94538457, -1.1126682 ,  0.22309966,  0.09018997])

# %%
fig, (ax1, ax2, ax3) = plt.subplots(ncols=3, figsize=(12, 4), dpi=150)
sns.histplot(np.random.normal(size=100), ax=ax1)
sns.histplot(np.random.normal(size=1000), ax=ax2)
sns.histplot(np.random.normal(size=10000), ax=ax3)
plt.show()

# %% [markdown]
# ## 1.2 T-student distribution

# %%
np.random.standard_t(df=4)
# Out:
# 0.9095745205391991

# %%
fig, (ax1, ax2, ax3) = plt.subplots(ncols=3, figsize=(12, 4), dpi=150)
sns.histplot(np.random.standard_t(df=30, size=100), ax=ax1)
sns.histplot(np.random.standard_t(df=30, size=1000), ax=ax2)
sns.histplot(np.random.standard_t(df=30, size=10000), ax=ax3)
plt.show()

# %% [markdown]
# ## 1.3 Gamma distribution

# %%
np.random.gamma(shape=2, size=100)
# Out:
# array([0.51198301, 4.75143544, 0.33111009, 1.3082891 , 1.99164495,
#        4.24321918, 0.21601933, 1.70994389, 1.86305835, 1.24902527,
#        0.9238776 , 0.39207211, 2.70284092, 6.99902459, 3.15551436,
#        2.01835428, 4.60586706, 2.25188906, 1.68044011, 6.25531442,
#        2.47320699, 0.98039946, 2.18729587, 1.16281104, 2.85150947,
#        3.70430942, 1.30510192, 0.25413678, 4.15339869, 0.99730045,
#        0.69982634, 0.48123858, 2.39434271, 2.59109052, 3.43565201,
#        1.08878201, 1.48399642, 3.35278508, 4.10376248, 0.13085335,
#        1.09689531, 1.06201296, 0.52156622, 3.8321593 , 0.39021812,
#        1.67720884, 1.5652389 , 0.08213228, 0.85766957, 2.2909228 ,
#        1.29293559, 2.16834767, 2.18402951, 3.38022299, 0.04681099,
#        1.76971624, 1.91120725, 0.78697513, 1.06962916, 0.33453509,
#        0.22782415, 0.5678044 , 1.36841711, 1.20253455, 1.10525236,
#        2.46170981, 1.78503661, 0.87219375, 1.04064963, 0.64247963,
#        3.05518656, 5.03258744, 0.8091456 , 0.36188885, 1.70299809,
#        2.25567213, 0.24790087, 3.66406943, 2.33092808, 0.09993759,
#        2.0254125 , 2.00191917, 2.16816872, 0.81202838, 1.95810263,
#        2.05590648, 1.12528999, 1.15456486, 2.92801889, 0.62963007,
#        0.37468925, 2.26437918, 1.11451721, 2.61422315, 0.86153441,
#        0.38130055, 1.58641148, 0.81330531, 1.92464334, 1.73757464])

# %%
fig, (ax1, ax2, ax3) = plt.subplots(ncols=3, figsize=(12, 4), dpi=150)
sns.histplot(np.random.gamma(shape=4, size=100), ax=ax1)
sns.histplot(np.random.gamma(shape=4, size=1000), ax=ax2)
sns.histplot(np.random.gamma(shape=4, size=100_000), ax=ax3)
plt.show()

# %%
fig, (ax1, ax2, ax3) = plt.subplots(ncols=3, figsize=(12, 4), dpi=150)
sns.histplot(np.random.gamma(shape=10, size=100), ax=ax1)
sns.histplot(np.random.gamma(shape=10, size=1000), ax=ax2)
sns.histplot(np.random.gamma(shape=10, size=100_000), ax=ax3)
plt.show()

# %% [markdown]
# # 2. Descriptive statistics

# %% [markdown]
# ## 2.1 Measure of central tendency

# %% [markdown]
# ### 2.1.1 Mean

# %%
ls = [1, 2, 3]
sum(ls) / len(ls)
# Out:
# 2.0

# %%
normal_dist = np.random.normal(size=100)

# %%
normal_dist.mean()
# Out:
# -0.11051991845455436

# %%
sns.histplot(normal_dist)
plt.axvline(normal_dist.mean(), color = 'r', ls='--')
plt.title('Normal dist Mean')
plt.show()

# %% [markdown]
# ### 2.1.2 Median

# %%
ls = [1, 2, 3] # median = 2
ls = [1, 2, 3, 4] # median=2.5
np.median(ls)
# Out:
# 2.5

# %%
np.median(normal_dist)
# Out:
# -0.15754664509373886

# %%
sns.histplot(normal_dist)
plt.axvline(np.median(normal_dist), color = 'r', ls='--')
plt.title('Normal dist Median')
plt.show()

# %% [markdown]
# ### 2.1.3 Mode

# %%
ls = [1, 2, 3, 4, 4] # mode=4

# %%
sns.histplot(normal_dist)
plt.axvline(np.median(normal_dist), color = 'r', ls='--')
plt.axvline(np.mean(normal_dist), color = 'y', ls='--')
plt.title('Normal dist Median')
plt.show()

# %%
df = pd.read_csv('../Practice_2/ds_salaries.csv')

sns.histplot(df.salary_in_usd)
plt.axvline(np.median(df.salary_in_usd), color = 'r', ls='--')
plt.axvline(np.mean(df.salary_in_usd), color = 'y', ls='--')
plt.show()

# %% [markdown]
# # 2.2 Measures of variability

# %% [markdown]
# ### 2.2.1 Variance

# %%
# Out:
# 63047.228497405435

# %%
print(np.var(df.salary_in_usd)) # dollras ^ 2
print(np.sqrt(np.var(df.salary_in_usd))) # sqrt(var) = std
# Out:
# 3974953021.204052
# 63047.228497405435

# %% [markdown]
# ### 2.2.2 Standard deviation

# %%
np.std(df.salary_in_usd) # dollras
# Out:
# 63047.228497405435

# %%
fig, (ax1, ax2, ax3, ax4) = plt.subplots(ncols=4, figsize=(12, 4), dpi=150, sharex=True)
sns.histplot(np.random.normal(scale=1, size=10000), ax=ax1)
sns.histplot(np.random.normal(scale=3, size=10000), ax=ax2)
sns.histplot(np.random.normal(scale=5, size=10000), ax=ax3)
sns.histplot(np.random.normal(scale=10, size=10000), ax=ax4)

ax1.set_title(f'Std={1}')
ax2.set_title(f'Std={3}')
ax3.set_title(f'Std={5}')
ax4.set_title(f'Std={10}')

plt.show()

# %% [markdown]
# ### 2.2.3 Ranage

# %%
max(df.salary_in_usd) - min(df.salary_in_usd)
# Out:
# 444868

# %% [markdown]
# ### 2.2.4 Quntiles / Percentiles / Quartiles

# %%
np.median(df.salary_in_usd) # 50% percentile
# Out:
# 135000.0

# %%
np.median(df.salary_in_usd)
# Out:
# 135000.0

# %%
np.percentile(df.salary_in_usd, 25) # 25% percentile
# Out:
# 95000.0

# %%
sns.histplot(df.salary_in_usd)
plt.axvline(np.percentile(df.salary_in_usd, 25), ls='--', label='25%', color='r')
plt.axvline(np.percentile(df.salary_in_usd, 75), ls='--', label='75%', color='r')
plt.axvline(np.percentile(df.salary_in_usd, 50), ls='--', label='50%', color='r')
plt.title('Percentiles plot')
plt.legend()
plt.show()

# %% [markdown]
# # 3. Three sigma rule (66 / 95 / 99.7)

# %%
# mean - 3 * std  mean + 3 * std

# %%
mean = df.salary_in_usd.mean()
std = df.salary_in_usd.std()


# 3 sigma rule
upper_bound = mean + 3 * std
lower_bound = mean - 3 * std # 99.7%

# 2 sigma rule
upper_bound_1 = mean + 2 * std # 95%
lower_bound_1 = mean - 2 * std

# 1 sigma rule
upper_bound_2 = mean + 1 * std # 66.7%
lower_bound_2 = mean - 1 * std

# %%
sns.histplot(df.salary_in_usd)

plt.axvline(upper_bound, color='r', label='$3 \sigma$', ls='--')
plt.axvline(lower_bound, color='r', ls='--')

plt.axvline(upper_bound_1, color='y', ls='--', label='$2 \sigma$')
plt.axvline(lower_bound_1, color='y', ls='--')

plt.axvline(upper_bound_2, color='c', ls='--', label='$1 \sigma$')
plt.axvline(lower_bound_2, color='c', ls='--')

plt.axvline(mean, color='purple', label='mean')
plt.legend()
plt.show()

# %% [markdown]
# # 1.5 IQR rule

# %% [markdown]
# IQR = inter quantile range
#
# IQR = Q75 - Q25

# %%
Q75  = np.percentile(df.salary_in_usd, 75)
Q25  = np.percentile(df.salary_in_usd, 25)
Q50  = np.percentile(df.salary_in_usd, 50)

IQR = Q75 - Q25

lower_bound = Q25 - 1.5 * IQR
upper_bound = Q75 + 1.5 * IQR

# %%
sns.histplot(df.salary_in_usd)
plt.axvline(upper_bound, color='c', label='3Q + 1.5IQR', ls='--')
plt.axvline(lower_bound, color='g', label='1Q - 1.5IQR', ls='--')
plt.title('IQR rule')
plt.axvline(Q50, color='r', label='Median')
plt.legend()
plt.show()

# %% [markdown]
# # 4. Rule/Law of big numbers

# %%
n_experiments = 1000
experiments = np.zeros(n_experiments)
for i in range(1, n_experiments):
    experiments[i] = np.random.randint(2, size=i).mean()

# %%
plt.plot(experiments)
plt.title('Law of big numbers')
plt.xlabel('N experiments')
plt.axhline(0.5, label='Expected value', color='r')
plt.ylabel('Probability of tail')
plt.legend()
plt.grid(alpha=.3)
plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(12, 4), dpi=150)
ax1.plot(experiments)
ax1.set_title('Tail probability over the experiments')
ax2.set_title('Distribution of tail probabilities')

ax1.set_xlabel('N experiments')
ax1.axhline(0.5, label='Expected value', color='r')
ax2.axvline(0.5, label='Expected value', color='r')
ax1.set_ylabel('Probability of tail')

sns.histplot(experiments, ax=ax2)
# ax1.legend()
# ax1.grid(alpha=.3)
plt.show()

# %% [markdown]
# # Central Limit Theorem (CLT)

# %%
gamma_distr = np.random.gamma(shape=2, size=100_000)

sns.histplot(gamma_distr, kde=True)
plt.title('Gamma dist')
plt.show()

# %%
subsample = np.random.choice(gamma_distr, size=1000)
mean_subsample = np.mean(subsample)

sns.histplot(subsample, kde=True)
plt.title(f'Sample Mean = {mean_subsample:.3f}')
plt.show()

# %%
subsample = np.random.choice(gamma_distr, size=1000)
mean_subsample = np.mean(subsample)

sns.histplot(subsample, kde=True)
plt.title(f'Sample Mean = {mean_subsample:.3f}')
plt.show()

# %%
n_experiments = 10_000
experiments_means = np.zeros(n_experiments)
for i in range(n_experiments):
    subsample = np.random.choice(gamma_distr, size=1000)
    mean_subsample = np.mean(subsample)
    experiments_means[i] = mean_subsample

sns.histplot(experiments_means, kde=True)
plt.show()

# %%
def central_limiting_theorem(func, n_experiments = 10_000, **kwargs):
    distr = func(**kwargs, size=100_000, )
    
    experiments_means = np.zeros(n_experiments)
    for i in range(n_experiments):
        subsample = np.random.choice(distr, size=1000)
        mean_subsample = np.mean(subsample)
        experiments_means[i] = mean_subsample
        
    
    fig, (ax1, ax2, ax3) = plt.subplots(ncols=3, figsize=(12, 4), dpi=150)
    sns.histplot(distr, ax=ax1, kde=True)
    ax1.set_title('Initial distribution')

    subsample = np.random.choice(distr, size=1000)
    mean_subsample = np.mean(subsample)

    sns.histplot(subsample, ax=ax2, kde=True)
    ax2.set_title(f'Sample Distr. with a Mean={mean_subsample:.3f}')


    sns.histplot(experiments_means, kde=True, ax=ax3)
    ax3.set_title(f'Distr. of {n_experiments} subsamples mean')
        
    plt.show()

# %% [markdown]
# ## CLT with initial Normal distribution

# %%
central_limiting_theorem(np.random.normal)

# %% [markdown]
# ## CLT with initial uniform distribution

# %%
central_limiting_theorem(np.random.uniform)

# %% [markdown]
# ## CLT with initial gamma distribution

# %%
central_limiting_theorem(np.random.gamma, shape = 3)

# %% [markdown]
# ## CLT with initial exponential distribution

# %%
central_limiting_theorem(np.random.exponential)
